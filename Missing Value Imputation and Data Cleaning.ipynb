# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("D:\\Future-500.csv")
df
# Out:
#       ID              Name      Industry  Inception  Employees State  \
# 0      1          Over-Hex      Software     2006.0       25.0    TN
# 1      2         Unimattax   IT Services     2009.0       36.0    PA
# 2      3          Greenfax        Retail     2012.0        NaN    SC
# 3      4         Blacklane   IT Services     2011.0       66.0    CA
# 4      5          Yearflex      Software     2013.0       45.0    WI
# ..   ...               ...           ...        ...        ...   ...
# 495  496  Buretteadmirable   IT Services     2009.0       93.0    ME
# 496  497  Inventtremendous  Construction     2009.0       24.0    MN
# 497  498    Overviewparrot        Retail     2011.0     7125.0    TX
# 498  499        Belaguerra   IT Services     2010.0      140.0    MI
# 499  500       Allpossible   IT Services     2011.0       24.0    CA
#
#                City       Revenue           Expenses      Profit Growth
# ...

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0        NaN    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#         Revenue           Expenses      Profit Growth
# 0   $9,684,527   1,130,700 Dollars   8553827.0    19%
# 1  $14,016,543     804,035 Dollars  13212508.0    20%
# 2   $9,746,272   1,044,375 Dollars   8701897.0    16%
# 3  $15,359,369   4,631,808 Dollars  10727561.0    19%
# 4   $8,567,910   4,374,841 Dollars   4193069.0    19%

# %%
df.isnull()
# Out:
#         ID   Name  Industry  Inception  Employees  State   City  Revenue  \
# 0    False  False     False      False      False  False  False    False
# 1    False  False     False      False      False  False  False    False
# 2    False  False     False      False       True  False  False    False
# 3    False  False     False      False      False  False  False    False
# 4    False  False     False      False      False  False  False    False
# ..     ...    ...       ...        ...        ...    ...    ...      ...
# 495  False  False     False      False      False  False  False    False
# 496  False  False     False      False      False  False  False    False
# 497  False  False     False      False      False  False  False    False
# 498  False  False     False      False      False  False  False    False
# 499  False  False     False      False      False  False  False    False
#
#      Expenses  Profit  Growth
# 0       False   False   False
# ...

# %%
df.isnull().count().sum()
# Out:
# 5500

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Industry     2
# Inception    1
# Employees    2
# State        4
# City         0
# Revenue      2
# Expenses     3
# Profit       2
# Growth       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         500 non-null    int64
#  1   Name       500 non-null    object
#  2   Industry   498 non-null    object
#  3   Inception  499 non-null    float64
#  4   Employees  498 non-null    float64
#  5   State      496 non-null    object
#  6   City       500 non-null    object
#  7   Revenue    498 non-null    object
#  8   Expenses   497 non-null    object
#  9   Profit     498 non-null    float64
#  10  Growth     499 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 43.1+ KB

# %%
df['Industry'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Industry, Length: 500, dtype: bool

# %%
df.describe()
# Out:
#                ID    Inception    Employees        Profit
# count  500.000000   499.000000   498.000000  4.980000e+02
# mean   250.500000  2010.174349   148.610442  6.539474e+06
# std    144.481833     3.228211   397.353657  3.869934e+06
# min      1.000000  1999.000000     1.000000  1.243400e+04
# 25%    125.750000  2009.000000    27.250000  3.272074e+06
# 50%    250.500000  2011.000000    56.000000  6.513366e+06
# 75%    375.250000  2012.000000   126.000000  9.303951e+06
# max    500.000000  2014.000000  7125.000000  1.962453e+07

# %%
df['Revenue']=df['Revenue'].str.lstrip("$")

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0        NaN    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#        Revenue           Expenses      Profit Growth
# 0   9,684,527   1,130,700 Dollars   8553827.0    19%
# 1  14,016,543     804,035 Dollars  13212508.0    20%
# 2   9,746,272   1,044,375 Dollars   8701897.0    16%
# 3  15,359,369   4,631,808 Dollars  10727561.0    19%
# 4   8,567,910   4,374,841 Dollars   4193069.0    19%

# %%
df['Revenue']=df['Revenue'].replace("," , "",regex=True)

# %%
df['Revenue']=df['Revenue'].replace(" " , "",regex=True)

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0        NaN    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#     Revenue           Expenses      Profit Growth
# 0   9684527  1,130,700 Dollars   8553827.0    19%
# 1  14016543    804,035 Dollars  13212508.0    20%
# 2   9746272  1,044,375 Dollars   8701897.0    16%
# 3  15359369  4,631,808 Dollars  10727561.0    19%
# 4   8567910  4,374,841 Dollars   4193069.0    19%

# %%
df['Expenses']=df['Expenses'].replace(",", "",regex=True)

# %%
df['Revenue']=df['Revenue'].replace(" " , "",regex=True)

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0        NaN    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#     Revenue         Expenses      Profit Growth
# 0   9684527  1130700 Dollars   8553827.0    19%
# 1  14016543   804035 Dollars  13212508.0    20%
# 2   9746272  1044375 Dollars   8701897.0    16%
# 3  15359369  4631808 Dollars  10727561.0    19%
# 4   8567910  4374841 Dollars   4193069.0    19%

# %%
df["Growth"]=df["Growth"].str.rstrip("%")

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0        NaN    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#     Revenue         Expenses      Profit Growth
# 0   9684527  1130700 Dollars   8553827.0     19
# 1  14016543   804035 Dollars  13212508.0     20
# 2   9746272  1044375 Dollars   8701897.0     16
# 3  15359369  4631808 Dollars  10727561.0     19
# 4   8567910  4374841 Dollars   4193069.0     19

# %%
df.describe()
# Out:
#                ID    Inception    Employees        Profit
# count  500.000000   499.000000   498.000000  4.980000e+02
# mean   250.500000  2010.174349   148.610442  6.539474e+06
# std    144.481833     3.228211   397.353657  3.869934e+06
# min      1.000000  1999.000000     1.000000  1.243400e+04
# 25%    125.750000  2009.000000    27.250000  3.272074e+06
# 50%    250.500000  2011.000000    56.000000  6.513366e+06
# 75%    375.250000  2012.000000   126.000000  9.303951e+06
# max    500.000000  2014.000000  7125.000000  1.962453e+07

# %%
df.isnull()
# Out:
#         ID   Name  Industry  Inception  Employees  State   City  Revenue  \
# 0    False  False     False      False      False  False  False    False
# 1    False  False     False      False      False  False  False    False
# 2    False  False     False      False       True  False  False    False
# 3    False  False     False      False      False  False  False    False
# 4    False  False     False      False      False  False  False    False
# ..     ...    ...       ...        ...        ...    ...    ...      ...
# 495  False  False     False      False      False  False  False    False
# 496  False  False     False      False      False  False  False    False
# 497  False  False     False      False      False  False  False    False
# 498  False  False     False      False      False  False  False    False
# 499  False  False     False      False      False  False  False    False
#
#      Expenses  Profit  Growth
# 0       False   False   False
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       ID             Name            Industry  Inception  Employees State  \
# 2      3         Greenfax              Retail     2012.0        NaN    SC
# 7      8        Rednimdox        Construction     2013.0       73.0    NY
# 10    11  Canecorporation              Health     2012.0        6.0   NaN
# 13    14         Techline                 NaN     2006.0       65.0    CA
# 14    15          Cityace                 NaN     2010.0       25.0    CO
# 16    17          Ganzlax         IT Services     2011.0       75.0    NJ
# 21    22       Lathotline              Health        NaN      103.0    VA
# 43    44        Ganzgreen        Construction     2010.0      224.0    TN
# 83    84       Drilldrill            Software     2010.0       30.0   NaN
# 266  267       Circlechop            Software     2010.0       14.0   NaN
# 331  332      Westminster  Financial Services     2010.0        NaN    MI
# 378  379        Stovepuck              Retail     2013.0       73.0   NaN
#
# ...

# %%
count = df[["State","City"]].isna().sum()

# %%
print(count)
# Out:
# State    4
# City     0
# dtype: int64

# %%
df[df["State"].isna()]
# Out:
#       ID             Name  Industry  Inception  Employees State  \
# 10    11  Canecorporation    Health     2012.0        6.0   NaN
# 83    84       Drilldrill  Software     2010.0       30.0   NaN
# 266  267       Circlechop  Software     2010.0       14.0   NaN
# 378  379        Stovepuck    Retail     2013.0       73.0   NaN
#
#               City   Revenue         Expenses     Profit Growth
# 10        New York  10597009  7591189 Dollars  3005820.0      7
# 83   San Francisco   7800620  2785799 Dollars  5014821.0     17
# 266  San Francisco   9067070  5929828 Dollars  3137242.0     20
# 378       New York  13814975  5904502 Dollars  7910473.0     10

# %%
df[df["City"]=="New York"]
# Out:
#       ID               Name            Industry  Inception  Employees State  \
# 10    11    Canecorporation              Health     2012.0        6.0   NaN
# 65    66           Zathtone            Software     2009.0      121.0    NY
# 131  132             Nimlux  Financial Services     2013.0      285.0    NY
# 214  215  Nervousdispatcher  Financial Services     2011.0       80.0    NY
# 324  325       Monotrichous            Software     2011.0       12.0    NY
# 330  331              Aspic              Retail     2001.0      130.0    NY
# 336  337       Asynchronous              Health     2013.0       22.0    NY
# 369  370        Haulbittern         IT Services     2010.0      138.0    NY
# 378  379          Stovepuck              Retail     2013.0       73.0   NaN
# 418  419    Twistedelephant         IT Services     2011.0      150.0    NY
# 473  474       Valuesbilled         IT Services     2013.0       95.0    NY
#
# ...

# %%
df["State"][10]='NY'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1982128690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["State"][10]='NY'

# %%
df[df["City"]=="New York"]
# Out:
#       ID               Name            Industry  Inception  Employees State  \
# 10    11    Canecorporation              Health     2012.0        6.0    NY
# 65    66           Zathtone            Software     2009.0      121.0    NY
# 131  132             Nimlux  Financial Services     2013.0      285.0    NY
# 214  215  Nervousdispatcher  Financial Services     2011.0       80.0    NY
# 324  325       Monotrichous            Software     2011.0       12.0    NY
# 330  331              Aspic              Retail     2001.0      130.0    NY
# 336  337       Asynchronous              Health     2013.0       22.0    NY
# 369  370        Haulbittern         IT Services     2010.0      138.0    NY
# 378  379          Stovepuck              Retail     2013.0       73.0   NaN
# 418  419    Twistedelephant         IT Services     2011.0      150.0    NY
# 473  474       Valuesbilled         IT Services     2013.0       95.0    NY
#
# ...

# %%
df["State"][378]='NY'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1440361811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["State"][378]='NY'

# %%
df[df["City"]=="New York"]
# Out:
#       ID               Name            Industry  Inception  Employees State  \
# 10    11    Canecorporation              Health     2012.0        6.0    NY
# 65    66           Zathtone            Software     2009.0      121.0    NY
# 131  132             Nimlux  Financial Services     2013.0      285.0    NY
# 214  215  Nervousdispatcher  Financial Services     2011.0       80.0    NY
# 324  325       Monotrichous            Software     2011.0       12.0    NY
# 330  331              Aspic              Retail     2001.0      130.0    NY
# 336  337       Asynchronous              Health     2013.0       22.0    NY
# 369  370        Haulbittern         IT Services     2010.0      138.0    NY
# 378  379          Stovepuck              Retail     2013.0       73.0    NY
# 418  419    Twistedelephant         IT Services     2011.0      150.0    NY
# 473  474       Valuesbilled         IT Services     2013.0       95.0    NY
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       ID         Name            Industry  Inception  Employees State  \
# 2      3     Greenfax              Retail     2012.0        NaN    SC
# 7      8    Rednimdox        Construction     2013.0       73.0    NY
# 13    14     Techline                 NaN     2006.0       65.0    CA
# 14    15      Cityace                 NaN     2010.0       25.0    CO
# 16    17      Ganzlax         IT Services     2011.0       75.0    NJ
# 21    22   Lathotline              Health        NaN      103.0    VA
# 43    44    Ganzgreen        Construction     2010.0      224.0    TN
# 83    84   Drilldrill            Software     2010.0       30.0   NaN
# 266  267   Circlechop            Software     2010.0       14.0   NaN
# 331  332  Westminster  Financial Services     2010.0        NaN    MI
#
#               City   Revenue         Expenses      Profit Growth
# 2       Greenville   9746272  1044375 Dollars   8701897.0     16
# 7         Woodside       NaN              NaN         NaN    NaN
# ...

# %%
count=df["Industry"].isna().sum()

# %%
count
# Out:
# 2

# %%
df[df["Industry"].isna()]
# Out:
#     ID      Name Industry  Inception  Employees State        City   Revenue  \
# 13  14  Techline      NaN     2006.0       65.0    CA   San Ramon  13898119
# 14  15   Cityace      NaN     2010.0       25.0    CO  Louisville   9254614
#
#            Expenses     Profit Growth
# 13  5470303 Dollars  8427816.0     23
# 14  6249498 Dollars  3005116.0      6

# %%
df[df["Inception"]==2010.0]
# Out:
#       ID              Name             Industry  Inception  Employees State  \
# 9     10         Stripfind   Financial Services     2010.0       25.0    FL
# 14    15           Cityace                  NaN     2010.0       25.0    CO
# 26    27          Ranktech  Government Services     2010.0      607.0    FL
# 29    30           Tambase             Software     2010.0       29.0    AZ
# 36    37         D-Zoocare   Financial Services     2010.0       98.0    WA
# ..   ...               ...                  ...        ...        ...   ...
# 468  469        Hoeforeach          IT Services     2010.0       25.0    WI
# 476  477     Soddenfurther   Financial Services     2010.0       20.0    CA
# 479  480  Excellencerecent               Health     2010.0      381.0    TX
# 489  490    Suckedregister               Retail     2010.0      100.0    TX
# 498  499        Belaguerra          IT Services     2010.0      140.0    MI
#
# ...

# %%
df[df["Name"]=='Cityace']
# Out:
#     ID     Name Industry  Inception  Employees State        City  Revenue  \
# 14  15  Cityace      NaN     2010.0       25.0    CO  Louisville  9254614
#
#            Expenses     Profit Growth
# 14  6249498 Dollars  3005116.0      6

# %%
df[df["City"]=='Louisville']
# Out:
#       ID            Name     Industry  Inception  Employees State        City  \
# 14    15         Cityace          NaN     2010.0       25.0    CO  Louisville
# 255  256  Colouredrecipe  IT Services     2010.0       34.0    KY  Louisville
#
#       Revenue         Expenses     Profit Growth
# 14    9254614  6249498 Dollars  3005116.0      6
# 255  13884717  5663096 Dollars  8221621.0     22

# %%
df["Industry"][14]='IT Services'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\3449398422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Industry"][14]='IT Services'

# %%
df[df["City"]=='San Ramon']
# Out:
#       ID             Name     Industry  Inception  Employees State       City  \
# 8      9          Lamtone  IT Services     2009.0       55.0    CA  San Ramon
# 13    14         Techline          NaN     2006.0       65.0    CA  San Ramon
# 464  465  Dashedcompounds  IT Services     2014.0       59.0    CA  San Ramon
#
#       Revenue         Expenses     Profit Growth
# 8    11757018  6482465 Dollars  5274553.0     30
# 13   13898119  5470303 Dollars  8427816.0     23
# 464  12791846  7879018 Dollars  4912828.0     23

# %%
df["Industry"][13]='IT Services'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\2065895781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Industry"][13]='IT Services'

# %%
df[df["Industry"].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Industry, Inception, Employees, State, City, Revenue, Expenses, Profit, Growth]
# Index: []

# %%
df[df["Employees"].isna()]
# Out:
#       ID         Name            Industry  Inception  Employees State  \
# 2      3     Greenfax              Retail     2012.0        NaN    SC
# 331  332  Westminster  Financial Services     2010.0        NaN    MI
#
#            City   Revenue         Expenses     Profit Growth
# 2    Greenville   9746272  1044375 Dollars  8701897.0     16
# 331        Troy  11861652  5245126 Dollars  6616526.0     15

# %%
df[df["Industry"]=='Retail'].describe()
# Out:
#                ID    Inception    Employees        Profit
# count   48.000000    48.000000    47.000000  4.800000e+01
# mean   265.750000  2010.416667   209.276596  7.482728e+06
# std    142.938835     3.375968  1033.738965  2.897292e+06
# min      3.000000  1999.000000     1.000000  8.153810e+05
# 25%    134.000000  2009.000000    15.500000  5.658476e+06
# 50%    286.000000  2011.000000    28.000000  7.326357e+06
# 75%    386.250000  2013.000000    70.000000  9.490338e+06
# max    498.000000  2014.000000  7125.000000  1.336925e+07

# %%
df["Employees"][2]=28.0
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\2945548489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Employees"][2]=28.0

# %%
df[df["Industry"]=='Financial Services'].describe()
# Out:
#                ID    Inception    Employees        Profit
# count   54.000000    54.000000    53.000000  5.400000e+01
# mean   273.351852  2009.888889   211.132075  8.295883e+06
# std    156.460877     2.717287   326.567170  2.167587e+06
# min      7.000000  2001.000000     3.000000  3.259485e+06
# 25%    112.250000  2009.000000    33.000000  6.638672e+06
# 50%    318.000000  2010.000000    80.000000  8.301998e+06
# 75%    399.000000  2011.000000   250.000000  1.019811e+07
# max    495.000000  2014.000000  1628.000000  1.220510e+07

# %%
df["Employees"][331]=80.0
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1842307310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Employees"][331]=80.0

# %%
df["Expenses"]=df["Expenses"].str.rstrip(" Dollars")

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0       28.0    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#     Revenue Expenses      Profit Growth
# 0   9684527  1130700   8553827.0     19
# 1  14016543   804035  13212508.0     20
# 2   9746272  1044375   8701897.0     16
# 3  15359369  4631808  10727561.0     19
# 4   8567910  4374841   4193069.0     19

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0       28.0    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#     Revenue Expenses      Profit Growth
# 0   9684527  1130700   8553827.0     19
# 1  14016543   804035  13212508.0     20
# 2   9746272  1044375   8701897.0     16
# 3  15359369  4631808  10727561.0     19
# 4   8567910  4374841   4193069.0     19

# %%
df[df.isnull().any(axis=1)]
# Out:
#       ID        Name      Industry  Inception  Employees State           City  \
# 7      8   Rednimdox  Construction     2013.0       73.0    NY       Woodside
# 16    17     Ganzlax   IT Services     2011.0       75.0    NJ         Iselin
# 21    22  Lathotline        Health        NaN      103.0    VA         McLean
# 43    44   Ganzgreen  Construction     2010.0      224.0    TN       Franklin
# 83    84  Drilldrill      Software     2010.0       30.0   NaN  San Francisco
# 266  267  Circlechop      Software     2010.0       14.0   NaN  San Francisco
#
#       Revenue Expenses      Profit Growth
# 7         NaN      NaN         NaN    NaN
# 16   14001180      NaN  11901180.0     18
# 21    9418303  7567233   1851070.0      2
# 43        NaN      NaN         NaN      9
# 83    7800620  2785799   5014821.0     17
# 266   9067070  5929828   3137242.0     20

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Industry     0
# Inception    1
# Employees    0
# State        2
# City         0
# Revenue      2
# Expenses     3
# Profit       2
# Growth       1
# dtype: int64

# %%
df[df["City"]=="San Francisco"]
# Out:
#       ID        Name  Industry  Inception  Employees State           City  \
# 83    84  Drilldrill  Software     2010.0       30.0   NaN  San Francisco
# 266  267  Circlechop  Software     2010.0       14.0   NaN  San Francisco
#
#      Revenue Expenses     Profit Growth
# 83   7800620  2785799  5014821.0     17
# 266  9067070  5929828  3137242.0     20

# %%
df["State"][83]='SF'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\3788798315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["State"][83]='SF'

# %%
df["State"][266]='SF'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1755374528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["State"][266]='SF'

# %%
df[df.isnull().any(axis=1)]
# Out:
#     ID        Name      Industry  Inception  Employees State      City  \
# 7    8   Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 16  17     Ganzlax   IT Services     2011.0       75.0    NJ    Iselin
# 21  22  Lathotline        Health        NaN      103.0    VA    McLean
# 43  44   Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#      Revenue Expenses      Profit Growth
# 7        NaN      NaN         NaN    NaN
# 16  14001180      NaN  11901180.0     18
# 21   9418303  7567233   1851070.0      2
# 43       NaN      NaN         NaN      9

# %%
df["Revenue"]=df.Revenue.astype(float)

# %%
df["Expenses"]=df.Expenses.astype(float)

# %%
revenue_constrction=df[df["Industry"]=='Construction']

# %%
revenue_constrction
# Out:
#       ID                Name      Industry  Inception  Employees State  \
# 7      8           Rednimdox  Construction     2013.0       73.0    NY
# 24    25            Tampware  Construction     2011.0       13.0    TX
# 28    29          Groovecane  Construction     2011.0       17.0    UT
# 38    39             Biotain  Construction     2012.0       62.0    IA
# 43    44           Ganzgreen  Construction     2010.0      224.0    TN
# 44    45            Zamhouse  Construction     2009.0       39.0    ME
# 45    46           Openjocon  Construction     2013.0       75.0    IL
# 48    49            Villadox  Construction     2012.0       20.0    CA
# 62    63           Sumzoomit  Construction     2010.0       32.0    MO
# 66    67            Vivacode  Construction     2009.0       28.0    LA
# 73    74               Conin  Construction     2009.0       23.0    CA
# 84    85            Tristone  Construction     2013.0       43.0    MD
# ...

# %%
revenue_constrction.describe().T
# Out:
#            count         mean           std        min         25%        50%  \
# ID          50.0      236.440  1.576288e+02        8.0       90.25      230.0
# Inception   50.0     2009.940  3.530682e+00     1999.0     2009.00     2011.0
# Employees   50.0       61.260  5.943091e+01        5.0       23.25       37.5
# Revenue     48.0  9158737.125  2.404913e+06  4419277.0  7729470.75  9055058.5
# Expenses    48.0  4453204.500  1.793322e+06   214470.0  3539327.50  4506975.5
# Profit      48.0  4705532.625  2.805089e+06    96073.0  2442148.25  4573280.5
#
#                    75%         max
# ID              354.00       497.0
# Inception      2012.00      2014.0
# Employees        75.00       272.0
# Revenue    10626473.75  18429577.0
# Expenses    5376596.25   8213905.0
# Profit      6801062.00  12616182.0

# %%
df[df["Revenue"].isna()]
# Out:
#     ID       Name      Industry  Inception  Employees State      City  \
# 7    8  Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 43  44  Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#     Revenue  Expenses  Profit Growth
# 7       NaN       NaN     NaN    NaN
# 43      NaN       NaN     NaN      9

# %%
df["Revenue"][7]=9055058.5
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\4011270014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Revenue"][7]=9055058.5

# %%
df["Revenue"][43]=9055058.5
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\781329487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Revenue"][43]=9055058.5

# %%
df[df.isnull().any(axis=1)]
# Out:
#     ID        Name      Industry  Inception  Employees State      City  \
# 7    8   Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 16  17     Ganzlax   IT Services     2011.0       75.0    NJ    Iselin
# 21  22  Lathotline        Health        NaN      103.0    VA    McLean
# 43  44   Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#        Revenue   Expenses      Profit Growth
# 7    9055058.5        NaN         NaN    NaN
# 16  14001180.0        NaN  11901180.0     18
# 21   9418303.0  7567233.0   1851070.0      2
# 43   9055058.5        NaN         NaN      9

# %%
df["Expenses"][7]='4506975.5'
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\2246218118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Expenses"][7]='4506975.5'

# %%
df["Expenses"][43]='4506975.5'

# %%
df[df.isna().any(axis=1)]
# Out:
#     ID        Name      Industry  Inception  Employees State      City  \
# 7    8   Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 16  17     Ganzlax   IT Services     2011.0       75.0    NJ    Iselin
# 21  22  Lathotline        Health        NaN      103.0    VA    McLean
# 43  44   Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#        Revenue   Expenses      Profit Growth
# 7    9055058.5  4506975.5         NaN    NaN
# 16  14001180.0        NaN  11901180.0     18
# 21   9418303.0  7567233.0   1851070.0      2
# 43   9055058.5  4506975.5         NaN      9

# %%
df["Expenses"][16]=(df["Revenue"][16])-(df["Profit"][16])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\219174223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Expenses"][16]=(df["Revenue"][16])-(df["Profit"][16])

# %%
df[df["Industry"]=='Health'].describe()
# Out:
#                ID    Inception    Employees       Revenue        Profit
# count   86.000000    85.000000    86.000000  8.600000e+01  8.600000e+01
# mean   260.813953  2010.894118   205.872093  8.811122e+06  2.929281e+06
# std    148.923234     3.008019   305.918590  1.978820e+06  2.075214e+06
# min     11.000000  2000.000000     6.000000  1.614585e+06  1.243400e+04
# 25%    123.000000  2010.000000    31.000000  7.588070e+06  1.311362e+06
# 50%    282.000000  2012.000000    86.500000  8.855710e+06  2.514786e+06
# 75%    389.000000  2013.000000   228.750000  1.001363e+07  4.480563e+06
# max    485.000000  2014.000000  1600.000000  1.531230e+07  9.174395e+06

# %%
df["Inception"][21]=2010.0
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\3376397242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Inception"][21]=2010.0

# %%
df[df.isna().any(axis=1)]
# Out:
#     ID       Name      Industry  Inception  Employees State      City  \
# 7    8  Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 43  44  Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#       Revenue   Expenses  Profit Growth
# 7   9055058.5  4506975.5     NaN    NaN
# 43  9055058.5  4506975.5     NaN      9

# %%
df[df["Industry"]=='Construction']
# Out:
#       ID                Name      Industry  Inception  Employees State  \
# 7      8           Rednimdox  Construction     2013.0       73.0    NY
# 24    25            Tampware  Construction     2011.0       13.0    TX
# 28    29          Groovecane  Construction     2011.0       17.0    UT
# 38    39             Biotain  Construction     2012.0       62.0    IA
# 43    44           Ganzgreen  Construction     2010.0      224.0    TN
# 44    45            Zamhouse  Construction     2009.0       39.0    ME
# 45    46           Openjocon  Construction     2013.0       75.0    IL
# 48    49            Villadox  Construction     2012.0       20.0    CA
# 62    63           Sumzoomit  Construction     2010.0       32.0    MO
# 66    67            Vivacode  Construction     2009.0       28.0    LA
# 73    74               Conin  Construction     2009.0       23.0    CA
# 84    85            Tristone  Construction     2013.0       43.0    MD
# ...

# %%
df["Growth"]=df.Growth.astype(float)

# %%
df[df["Industry"]=='Construction'].describe()
# Out:
#               ID    Inception  Employees       Revenue        Profit  \
# count   50.00000    50.000000   50.00000  5.000000e+01  4.800000e+01
# mean   236.44000  2009.940000   61.26000  9.154590e+06  4.705533e+06
# std    157.62875     3.530682   59.43091  2.355412e+06  2.805089e+06
# min      8.00000  1999.000000    5.00000  4.419277e+06  9.607300e+04
# 25%     90.25000  2009.000000   23.25000  7.761712e+06  2.442148e+06
# 50%    230.00000  2011.000000   37.50000  9.055058e+06  4.573280e+06
# 75%    354.00000  2012.000000   75.00000  1.047976e+07  6.801062e+06
# max    497.00000  2014.000000  272.00000  1.842958e+07  1.261618e+07
#
#           Growth
# count  49.000000
# mean   10.061224
# std     3.071429
# min     5.000000
# 25%     8.000000
# 50%    10.000000
# 75%    12.000000
# max    19.000000

# %%
df["Growth"][7]=10.0
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\3110848792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Growth"][7]=10.0

# %%
df[df.isnull().any(axis=1)]
# Out:
#     ID       Name      Industry  Inception  Employees State      City  \
# 7    8  Rednimdox  Construction     2013.0       73.0    NY  Woodside
# 43  44  Ganzgreen  Construction     2010.0      224.0    TN  Franklin
#
#       Revenue   Expenses  Profit  Growth
# 7   9055058.5  4506975.5     NaN    10.0
# 43  9055058.5  4506975.5     NaN     9.0

# %%
df['Expenses']=df.Expenses.astype(float)

# %%
type(df['Revenue'])
# Out:
# pandas.core.series.Series

# %%
df['Profit'][7]=(df['Revenue'][7])-(df['Expenses'][7])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\128114387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit'][7]=(df['Revenue'][7])-(df['Expenses'][7])

# %%
df['Profit'][43]=(df['Revenue'][43])-(df['Expenses'][43])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1405208390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit'][43]=(df['Revenue'][43])-(df['Expenses'][43])

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Industry, Inception, Employees, State, City, Revenue, Expenses, Profit, Growth]
# Index: []

# %%
df.isnull().count()
# Out:
# ID           500
# Name         500
# Industry     500
# Inception    500
# Employees    500
# State        500
# City         500
# Revenue      500
# Expenses     500
# Profit       500
# Growth       500
# dtype: int64

# %%
df.describe()
# Out:
#                ID    Inception    Employees       Revenue      Expenses  \
# count  500.000000   500.000000   500.000000  5.000000e+02  5.000000e+02
# mean   250.500000  2010.174000   148.232000  1.083801e+07  4.306501e+06
# std    144.481833     3.224985   396.605024  3.189223e+06  2.111938e+06
# min      1.000000  1999.000000     1.000000  1.614585e+06  7.121900e+04
# 25%    125.750000  2009.000000    27.750000  8.696767e+06  2.758423e+06
# 50%    250.500000  2011.000000    56.000000  1.064063e+07  4.366960e+06
# 75%    375.250000  2012.000000   126.000000  1.310111e+07  5.805174e+06
# max    500.000000  2014.000000  7125.000000  2.181005e+07  9.860686e+06
#
#              Profit      Growth
# count  5.000000e+02  500.000000
# mean   6.531508e+06   14.368000
# std    3.864219e+06    6.889376
# min    1.243400e+04   -3.000000
# 25%    3.297251e+06    8.000000
# 50%    6.503795e+06   15.000000
# 75%    9.283554e+06   20.000000
# max    1.962453e+07   30.000000

# %%
df.head()
# Out:
#    ID       Name     Industry  Inception  Employees State            City  \
# 0   1   Over-Hex     Software     2006.0       25.0    TN        Franklin
# 1   2  Unimattax  IT Services     2009.0       36.0    PA  Newtown Square
# 2   3   Greenfax       Retail     2012.0       28.0    SC      Greenville
# 3   4  Blacklane  IT Services     2011.0       66.0    CA          Orange
# 4   5   Yearflex     Software     2013.0       45.0    WI         Madison
#
#       Revenue   Expenses      Profit  Growth
# 0   9684527.0  1130700.0   8553827.0    19.0
# 1  14016543.0   804035.0  13212508.0    20.0
# 2   9746272.0  1044375.0   8701897.0    16.0
# 3  15359369.0  4631808.0  10727561.0    19.0
# 4   8567910.0  4374841.0   4193069.0    19.0

# %%
Industry_Software=df[df["Industry"]=='Software']

# %%
Industry_Software['Revenue']
# Out:
# 0       9684527.0
# 4       8567910.0
# 19     10410628.0
# 23      8304480.0
# 27      5231275.0
#           ...
# 341    10067223.0
# 344     4422083.0
# 347     8215508.0
# 360    10188123.0
# 365     7047541.0
# Name: Revenue, Length: 64, dtype: float64

# %%
Industry_Software.plot()
# Out:
# <AxesSubplot:>

# %%
df['Industry'].unique()
# Out:
# array(['Software', 'IT Services', 'Retail', 'Financial Services',
#        'Construction', 'Health', 'Government Services'], dtype=object)

# %%
Industry_IT_Services=df[df["Industry"]=='IT Services']

# %%
Industry_IT_Services.plot()
# Out:
# <AxesSubplot:>

# %%
Industry_Retail=df[df["Industry"]=='Retail']

# %%
Industry_Retail.plot()
# Out:
# <AxesSubplot:>

# %%
Industry_Financial_Services=df[df["Industry"]=='Financial Services']

# %%
Industry_Financial_Services.plot()
# Out:
# <AxesSubplot:>

# %%
Industry_Construction=df[df["Industry"]=='Construction']

# %%
Industry_Construction.plot()
# Out:
# <AxesSubplot:>

# %%
Industry_Health=df[df["Industry"]=='Health']

# %%
Industry_Health.plot()
# Out:
# <AxesSubplot:>

# %%
Industry_Government_Services=df[df["Industry"]=='Government Services']

# %%
Industry_Government_Services.plot()
# Out:
# <AxesSubplot:>

# %%
insights=df[["Revenue","Expenses"]]

# %%
insights.describe()
# Out:
#             Revenue      Expenses
# count  5.000000e+02  5.000000e+02
# mean   1.083801e+07  4.306501e+06
# std    3.189223e+06  2.111938e+06
# min    1.614585e+06  7.121900e+04
# 25%    8.696767e+06  2.758423e+06
# 50%    1.064063e+07  4.366960e+06
# 75%    1.310111e+07  5.805174e+06
# max    2.181005e+07  9.860686e+06

# %%
df.plot(x = 'Revenue', y = 'Expenses', style = 'o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()
